# %%
<!DOCTYPE html>
<html lang="ko">
<head>
  <meta charset="utf-8"/>
  <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
  <title>신청 준비 | 지원금 워크플로우 매니저</title>
  <script src="https://cdn.tailwindcss.com?plugins=forms,container-queries"></script>
  <link rel="preconnect" href="https://fonts.googleapis.com"/>
  <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin/>
  <link href="https://fonts.googleapis.com/css2?family=Inter:wght@400;500;600;700;800;900&family=Noto+Sans+KR:wght@400;500;700;800&display=swap" rel="stylesheet"/>
  <link href="https://fonts.googleapis.com/css2?family=Material+Symbols+Outlined:wght,FILL@200..700,0..1" rel="stylesheet"/>
  <script>
    tailwind.config = {
      darkMode: "class",
      theme: {
        extend: {
          colors: {
            primary: "#0B5FFF",
            "primary-dark": "#0847C7"
          },
          boxShadow: {
            soft: "0 8px 24px rgba(15,23,42,.06)"
          },
          borderRadius: {
            xl: "1rem",
            "2xl": "1.25rem"
          }
        }
      }
    }
  </script>
  <style>
    :root{
      --primary:#0B5FFF;
      --primary-2:#0847C7;
      --bg:#F6F8FC;
      --line:#E5EAF2;
      --text:#0F172A;
      --muted:#64748B;
      --card:#FFFFFF;
      --success:#16A34A;
      --warning:#D97706;
      --danger:#DC2626;
      --navy:#0F172A;
    }
    *{box-sizing:border-box;}
    body{font-family:'Inter','Noto Sans KR',sans-serif;background:var(--bg);color:var(--text);}
    .page-shell{min-height:100vh;}
    .sidebar-link{display:flex;align-items:center;gap:.75rem;border-radius:1rem;padding:.875rem 1rem;font-weight:600;color:#334155;transition:all .18s ease;}
    .sidebar-link:hover{background:#eef4ff;color:var(--primary);}
    .sidebar-link.active{background:#eaf1ff;color:var(--primary);}
    .badge{display:inline-flex;align-items:center;gap:.35rem;border-radius:999px;padding:.3rem .7rem;font-size:.78rem;font-weight:700;}
    .badge-blue{background:#eaf1ff;color:var(--primary);}
    .badge-green{background:#eaf8ef;color:var(--success);}
    .badge-amber{background:#fff6e8;color:var(--warning);}
    .badge-red{background:#fdecec;color:var(--danger);}
    .card{background:var(--card);border:1px solid var(--line);border-radius:1.25rem;box-shadow:0 8px 24px rgba(15,23,42,.04);}
    .muted{color:var(--muted);}
    .metric{font-size:2rem;font-weight:900;letter-spacing:-.03em;}
    .pill-input{border:1px solid var(--line);border-radius:999px;background:#fff;padding:.8rem 1rem;}
    .step-scroll::-webkit-scrollbar{height:6px;}
    .step-scroll::-webkit-scrollbar-thumb{background:#cbd5e1;border-radius:999px;}
    .step-chip{border:1px solid var(--line);background:#fff;border-radius:1rem;padding:1rem;min-width:176px;}
    .step-chip.active{background:linear-gradient(135deg,var(--primary),var(--primary-2));color:#fff;border-color:transparent;box-shadow:0 12px 30px rgba(11,95,255,.25);}
    .step-chip.done{border-color:#D8E7FF;background:#F9FBFF;}
    .hero-grid{display:grid;grid-template-columns:1.5fr .85fr;gap:1.25rem;}
    .dashboard-grid{display:grid;grid-template-columns:2fr 1fr;gap:1.5rem;}
    .stats-grid{display:grid;grid-template-columns:1fr 1fr;gap:1.25rem;}
    .progress-ring{width:72px;height:72px;}
    .list-item{display:flex;align-items:flex-start;justify-content:space-between;gap:1rem;padding:1rem 1.5rem;}
    .list-item + .list-item{border-top:1px solid var(--line);}
    @media (max-width: 1180px){
      .dashboard-grid{grid-template-columns:1fr;}
    }
    @media (max-width: 980px){
      .hero-grid,.stats-grid{grid-template-columns:1fr;}
      aside{display:none;}
    }
  </style>
</head>
<body>
  <div class="page-shell flex">
    <aside class="w-[280px] shrink-0 border-r border-slate-200 bg-white/90 backdrop-blur">
      <div class="flex h-full flex-col px-5 py-6">
        <div class="mb-8">
          <div class="text-[30px] font-black tracking-[-0.03em] text-[var(--primary)]">지원금 워크플로우 매니저</div>
          <div class="mt-1 text-sm font-medium text-slate-500">지원금 신청 전 과정을 한 화면에서 관리</div>
        </div>
        <div class="mb-4 rounded-2xl bg-slate-50 p-4">
          <div class="text-xs font-bold uppercase tracking-[0.18em] text-slate-400">현재 선택 기업</div>
          <div class="mt-2 flex items-center justify-between gap-3">
            <div>
              <div class="font-bold">(주)테크원</div>
              <div class="text-sm text-slate-500">제조업 · 반도체 장비</div>
            </div>
            <span class="material-symbols-outlined text-slate-400">expand_more</span>
          </div>
        </div>
        <nav class="space-y-2 overflow-y-auto pr-1">
          <a href="platform_02.html" class="sidebar-link">
            <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700"><span class="material-symbols-outlined text-[20px]">storefront</span></span>
            <span class="flex-1"><span class="block text-xs text-slate-400">STEP 01</span><span class="block">기업 등록</span></span>
          </a>
          <a href="platform_03.html" class="sidebar-link">
            <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700"><span class="material-symbols-outlined text-[20px]">groups</span></span>
            <span class="flex-1"><span class="block text-xs text-slate-400">STEP 02</span><span class="block">직원 업로드</span></span>
          </a>
          <a href="platform_05.html" class="sidebar-link">
            <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700"><span class="material-symbols-outlined text-[20px]">event_note</span></span>
            <span class="flex-1"><span class="block text-xs text-slate-400">STEP 03</span><span class="block">인사 이벤트</span></span>
          </a>
          <a href="platform_06.html" class="sidebar-link">
            <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700"><span class="material-symbols-outlined text-[20px]">monitoring</span></span>
            <span class="flex-1"><span class="block text-xs text-slate-400">STEP 04</span><span class="block">지원금 진단</span></span>
          </a>
          <a href="platform_07.html" class="sidebar-link">
            <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700"><span class="material-symbols-outlined text-[20px]">quiz</span></span>
            <span class="flex-1"><span class="block text-xs text-slate-400">STEP 05</span><span class="block">추가 질문</span></span>
          </a>
          <a href="platform_08.html" class="sidebar-link">
            <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700"><span class="material-symbols-outlined text-[20px]">balance</span></span>
            <span class="flex-1"><span class="block text-xs text-slate-400">STEP 06</span><span class="block">충돌 검토</span></span>
          </a>
          <a href="platform_01_추가통일.html" class="sidebar-link active">
            <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700"><span class="material-symbols-outlined text-[20px]">folder_open</span></span>
            <span class="flex-1"><span class="block text-xs text-slate-400">STEP 07</span><span class="block">신청 준비</span></span>
          </a>
          <a href="platform_09.html" class="sidebar-link">
            <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700"><span class="material-symbols-outlined text-[20px]">edit_document</span></span>
            <span class="flex-1"><span class="block text-xs text-slate-400">STEP 08</span><span class="block">신청서 자동작성</span></span>
          </a>
          <a href="platform_10.html" class="sidebar-link">
            <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700"><span class="material-symbols-outlined text-[20px]">task</span></span>
            <span class="flex-1"><span class="block text-xs text-slate-400">STEP 09</span><span class="block">제출 관리</span></span>
          </a>
          <a href="platform_11.html" class="sidebar-link">
            <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700"><span class="material-symbols-outlined text-[20px]">shield</span></span>
            <span class="flex-1"><span class="block text-xs text-slate-400">STEP 10</span><span class="block">사후관리</span></span>
          </a>
        </nav>
        <div class="mt-auto pt-6">
          <div class="rounded-2xl bg-slate-900 px-4 py-5 text-white">
            <div class="text-xs font-bold uppercase tracking-[0.18em] text-slate-400">운영 메모</div>
            <p class="mt-2 text-sm leading-6 text-slate-200">브랜드, 용어, 상태값, 버튼 위치를 통합 기준으로 다시 정리한 신청 준비 화면입니다.</p>
          </div>
        </div>
      </div>
    </aside>

    <div class="flex min-w-0 flex-1 flex-col">
      <header class="sticky top-0 z-10 border-b border-slate-200 bg-white/85 backdrop-blur">
        <div class="flex h-20 items-center justify-between gap-6 px-8">
          <div class="flex items-center gap-4">
            <span class="badge badge-blue">워크플로우 진행 중</span>
            <div>
              <div class="text-sm font-semibold text-slate-500">기업명</div>
              <div class="font-bold">(주)테크원</div>
            </div>
          </div>
          <div class="flex min-w-0 flex-1 items-center justify-end gap-4">
            <div class="pill-input hidden w-full max-w-md items-center gap-2 md:flex">
              <span class="material-symbols-outlined text-slate-400">search</span>
              <span class="text-sm text-slate-400">검색, 담당자, 서류명, 제도명…</span>
            </div>
            <button class="inline-flex h-11 w-11 items-center justify-center rounded-2xl border border-slate-200 bg-white text-slate-600">
              <span class="material-symbols-outlined">notifications</span>
            </button>
            <button class="inline-flex items-center gap-3 rounded-2xl border border-slate-200 bg-white px-4 py-2.5">
              <span class="inline-flex h-9 w-9 items-center justify-center rounded-full bg-emerald-50 text-emerald-700 text-sm font-bold">TW</span>
              <span class="text-sm font-semibold">신청 준비</span>
            </button>
          </div>
        </div>
      </header>

      <main class="flex-1 space-y-8 px-8 py-8">
        <section class="hero-grid">
          <div class="card p-7">
            <div class="flex flex-wrap items-start justify-between gap-4">
              <div>
                <div class="badge badge-blue">STEP 07</div>
                <h1 class="mt-4 text-[38px] font-black tracking-[-0.04em]">신청 준비</h1>
                <p class="mt-3 max-w-3xl text-base leading-7 text-slate-500">누락 항목, AI 검토 요약, 제출 일정, 다음 액션을 한 구조로 묶어 신청 전 마지막 확인을 빠르게 끝낼 수 있도록 통일한 화면입니다.</p>
              </div>
              <div class="flex flex-wrap gap-3">
                <button class="inline-flex items-center gap-2 rounded-2xl border border-[var(--line)] bg-white px-5 py-3 text-sm font-semibold text-slate-700 transition hover:bg-slate-50">이전 이력 보기</button>
                <button class="inline-flex items-center gap-2 rounded-2xl border border-[var(--primary)] bg-[var(--primary)] px-5 py-3 text-sm font-semibold text-white shadow-[0_10px_24px_rgba(11,95,255,.22)] transition hover:bg-[var(--primary-2)]">
                  <span>신청서 작성 시작</span>
                  <span class="material-symbols-outlined text-[18px]">arrow_forward</span>
                </button>
              </div>
            </div>
          </div>
          <div class="grid gap-4">
            <div class="card p-6">
              <div class="flex items-start justify-between gap-3">
                <div>
                  <p class="text-sm font-semibold text-slate-500">전체 진행률</p>
                  <p class="metric mt-3">70%</p>
                  <p class="mt-2 text-sm muted">10단계 중 7단계 진행 중</p>
                </div>
                <span class="badge badge-blue">현재 단계</span>
              </div>
            </div>
            <div class="card p-6">
              <div class="flex items-start justify-between gap-3">
                <div>
                  <p class="text-sm font-semibold text-slate-500">수령 가능 지원금</p>
                  <p class="metric mt-3">12,500,000원</p>
                  <p class="mt-2 text-sm muted">진단 결과 기반 합산</p>
                </div>
                <span class="badge badge-green">전월 대비 15% 상승</span>
              </div>
            </div>
          </div>
        </section>

        <section class="card p-6">
          <div class="flex items-center justify-between gap-4">
            <div>
              <p class="text-sm font-semibold text-slate-500">워크플로우 보드</p>
              <h2 class="mt-1 text-xl font-black tracking-[-0.02em]">현재 신청 준비 단계에 머물러 있습니다</h2>
            </div>
            <span class="badge badge-amber">다음 단계: 신청서 자동작성</span>
          </div>
          <div class="step-scroll mt-6 overflow-x-auto pb-2">
            <div class="flex min-w-max items-center gap-4">
              <div class="step-chip done">
                <div class="flex items-center justify-between">
                  <span class="text-xs font-bold uppercase tracking-[0.14em] text-slate-400">STEP 01</span>
                  <span class="material-symbols-outlined text-[18px] text-emerald-500">check_circle</span>
                </div>
                <div class="mt-3 font-bold">기업 등록</div>
                <div class="mt-1 text-sm text-slate-500">완료 · 2024.03.15</div>
              </div>
              <span class="material-symbols-outlined text-slate-300">chevron_right</span>
              <div class="step-chip done">
                <div class="flex items-center justify-between">
                  <span class="text-xs font-bold uppercase tracking-[0.14em] text-slate-400">STEP 02</span>
                  <span class="material-symbols-outlined text-[18px] text-emerald-500">check_circle</span>
                </div>
                <div class="mt-3 font-bold">직원 업로드</div>
                <div class="mt-1 text-sm text-slate-500">완료 · 2024.03.15</div>
              </div>
              <span class="material-symbols-outlined text-slate-300">chevron_right</span>
              <div class="step-chip done">
                <div class="flex items-center justify-between">
                  <span class="text-xs font-bold uppercase tracking-[0.14em] text-slate-400">STEP 03</span>
                  <span class="material-symbols-outlined text-[18px] text-emerald-500">check_circle</span>
                </div>
                <div class="mt-3 font-bold">인사 이벤트</div>
                <div class="mt-1 text-sm text-slate-500">완료 · 2024.03.16</div>
              </div>
              <span class="material-symbols-outlined text-slate-300">chevron_right</span>
              <div class="step-chip done">
                <div class="flex items-center justify-between">
                  <span class="text-xs font-bold uppercase tracking-[0.14em] text-slate-400">STEP 04</span>
                  <span class="material-symbols-outlined text-[18px] text-emerald-500">check_circle</span>
                </div>
                <div class="mt-3 font-bold">지원금 진단</div>
                <div class="mt-1 text-sm text-slate-500">완료 · 2024.03.17</div>
              </div>
              <span class="material-symbols-outlined text-slate-300">chevron_right</span>
              <div class="step-chip done">
                <div class="flex items-center justify-between">
                  <span class="text-xs font-bold uppercase tracking-[0.14em] text-slate-400">STEP 05</span>
                  <span class="material-symbols-outlined text-[18px] text-emerald-500">check_circle</span>
                </div>
                <div class="mt-3 font-bold">추가 질문</div>
                <div class="mt-1 text-sm text-slate-500">완료 · 2024.03.18</div>
              </div>
              <span class="material-symbols-outlined text-slate-300">chevron_right</span>
              <div class="step-chip done">
                <div class="flex items-center justify-between">
                  <span class="text-xs font-bold uppercase tracking-[0.14em] text-slate-400">STEP 06</span>
                  <span class="material-symbols-outlined text-[18px] text-emerald-500">check_circle</span>
                </div>
                <div class="mt-3 font-bold">충돌 검토</div>
                <div class="mt-1 text-sm text-slate-500">완료 · 2024.03.18</div>
              </div>
              <span class="material-symbols-outlined text-[var(--primary)]">chevron_right</span>
              <div class="step-chip active">
                <div class="flex items-center justify-between">
                  <span class="text-xs font-bold uppercase tracking-[0.14em] text-white/70">STEP 07</span>
                  <span class="inline-flex h-2.5 w-2.5 rounded-full bg-white"></span>
                </div>
                <div class="mt-3 font-bold text-lg">신청 준비</div>
                <div class="mt-1 text-sm text-white/80">서류 최종 검토 중</div>
                <div class="mt-4 h-2 rounded-full bg-white/20">
                  <div class="h-2 w-[65%] rounded-full bg-white"></div>
                </div>
              </div>
              <span class="material-symbols-outlined text-slate-200">chevron_right</span>
              <div class="step-chip">
                <div class="text-xs font-bold uppercase tracking-[0.14em] text-slate-400">STEP 08</div>
                <div class="mt-3 font-bold text-slate-400">신청서 자동작성</div>
              </div>
              <span class="material-symbols-outlined text-slate-200">chevron_right</span>
              <div class="step-chip">
                <div class="text-xs font-bold uppercase tracking-[0.14em] text-slate-400">STEP 09</div>
                <div class="mt-3 font-bold text-slate-400">제출 관리</div>
              </div>
              <span class="material-symbols-outlined text-slate-200">chevron_right</span>
              <div class="step-chip">
                <div class="text-xs font-bold uppercase tracking-[0.14em] text-slate-400">STEP 10</div>
                <div class="mt-3 font-bold text-slate-400">사후관리</div>
              </div>
            </div>
          </div>
        </section>

        <section class="dashboard-grid">
          <div class="space-y-6">
            <div class="stats-grid">
              <article class="card p-6">
                <div class="flex items-center gap-2">
                  <span class="material-symbols-outlined text-[var(--primary)]">psychology</span>
                  <h3 class="text-lg font-extrabold tracking-[-0.01em]">AI 검토 요약</h3>
                </div>
                <div class="mt-5 space-y-4 text-sm">
                  <div class="flex items-center gap-3">
                    <span class="h-2.5 w-2.5 rounded-full bg-emerald-500"></span>
                    <span>고용보험 데이터 정합성 검증 완료</span>
                  </div>
                  <div class="flex items-center gap-3">
                    <span class="h-2.5 w-2.5 rounded-full bg-amber-500"></span>
                    <span>일부 직원 계약서 형태 재확인 필요</span>
                  </div>
                </div>
                <button class="mt-6 inline-flex items-center gap-1 text-sm font-bold text-[var(--primary)]">상세 리포트 보기 <span class="material-symbols-outlined text-[16px]">arrow_right_alt</span></button>
              </article>

              <article class="card border-[var(--primary)]/10 bg-[rgba(11,95,255,.04)] p-6">
                <div class="flex items-center gap-2">
                  <span class="material-symbols-outlined text-[var(--primary)]">payments</span>
                  <h3 class="text-lg font-extrabold tracking-[-0.01em]">수령 가능 지원금</h3>
                </div>
                <div class="mt-8 flex items-end justify-between gap-3">
                  <div>
                    <div class="metric text-[var(--primary)]">12,500,000</div>
                    <div class="mt-1 text-sm font-semibold text-slate-500">원</div>
                  </div>
                  <span class="badge badge-green">전월 대비 15% 상승</span>
                </div>
              </article>
            </div>

            <article class="card overflow-hidden">
              <div class="flex items-center justify-between border-b border-slate-100 bg-slate-50/70 px-6 py-4">
                <h3 class="flex items-center gap-2 text-lg font-extrabold tracking-[-0.01em]"><span class="material-symbols-outlined text-amber-500">warning</span>누락된 항목 및 조치 필요</h3>
                <span class="badge badge-amber">총 2건</span>
              </div>
              <div>
                <div class="list-item">
                  <div class="flex items-start gap-4">
                    <div class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-amber-50 text-amber-600">
                      <span class="material-symbols-outlined text-[18px]">attachment</span>
                    </div>
                    <div>
                      <div class="font-bold">신규 입사자 명단(3월) - 서명 누락</div>
                      <div class="mt-1 text-sm text-slate-500">인사 이벤트 단계에서 파일 재업로드 필요</div>
                    </div>
                  </div>
                  <button class="rounded-xl border border-[var(--primary)]/20 px-4 py-2 text-sm font-bold text-[var(--primary)] hover:bg-[rgba(11,95,255,.04)]">해결하기</button>
                </div>
                <div class="list-item">
                  <div class="flex items-start gap-4">
                    <div class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-amber-50 text-amber-600">
                      <span class="material-symbols-outlined text-[18px]">assignment_late</span>
                    </div>
                    <div>
                      <div class="font-bold">청년 고용 추가 장려금 - 보완 답변</div>
                      <div class="mt-1 text-sm text-slate-500">추가 질문 단계에서 2개 항목 미답변</div>
                    </div>
                  </div>
                  <button class="rounded-xl border border-[var(--primary)]/20 px-4 py-2 text-sm font-bold text-[var(--primary)] hover:bg-[rgba(11,95,255,.04)]">해결하기</button>
                </div>
              </div>
            </article>
          </div>

          <div class="space-y-6">
            <article class="card p-6">
              <div class="text-xs font-bold uppercase tracking-[0.18em] text-slate-400">현재 제출 상태</div>
              <div class="mt-4 flex items-center gap-4">
                <div class="relative progress-ring shrink-0">
                  <svg viewBox="0 0 36 36" class="h-full w-full -rotate-90">
                    <path d="M18 2.0845a15.9155 15.9155 0 1 1 0 31.831a15.9155 15.9155 0 1 1 0-31.831" fill="none" stroke="#E5EAF2" stroke-width="3"></path>
                    <path d="M18 2.0845a15.9155 15.9155 0 1 1 0 31.831a15.9155 15.9155 0 1 1 0-31.831" fill="none" stroke="#0B5FFF" stroke-width="3" stroke-linecap="round" stroke-dasharray="70,100"></path>
                  </svg>
                  <div class="absolute inset-0 flex items-center justify-center text-sm font-black">70%</div>
                </div>
                <div>
                  <span class="badge badge-blue">준비 중</span>
                  <div class="mt-2 font-bold">신청서 작성 대기</div>
                  <div class="mt-1 text-sm text-slate-500">예정일: 2024.03.20</div>
                </div>
              </div>
            </article>

            <article class="rounded-[1.25rem] bg-[var(--navy)] p-6 text-white shadow-[0_18px_36px_rgba(15,23,42,.18)]">
              <div class="text-xs font-bold uppercase tracking-[0.18em] text-slate-400">Next Action</div>
              <h3 class="mt-3 text-[28px] font-black tracking-[-0.03em] leading-[1.15]">신청서 자동 작성을 위해<br/>검토를 완료해주세요.</h3>
              <p class="mt-3 text-sm leading-6 text-slate-300">누락 2건만 해결하면 다음 단계로 자동 연결됩니다.</p>
              <button class="mt-6 inline-flex w-full items-center justify-center gap-2 rounded-2xl bg-white px-5 py-3 text-sm font-bold text-slate-900">검토 완료 및 다음 단계 <span class="material-symbols-outlined text-[18px]">arrow_forward</span></button>
            </article>

            <article class="card p-6">
              <div class="flex items-center justify-between gap-3">
                <h3 class="text-lg font-extrabold tracking-[-0.01em]">주요 일정</h3>
                <span class="text-xs font-semibold text-slate-400">2024년 3월</span>
              </div>
              <div class="mt-5 space-y-4">
                <div class="flex gap-4">
                  <div class="w-10 text-center">
                    <div class="text-[11px] font-bold uppercase text-slate-400">Mon</div>
                    <div class="text-lg font-black">18</div>
                  </div>
                  <div class="flex-1 rounded-2xl border-l-4 border-[var(--primary)] bg-slate-50 px-4 py-3">
                    <div class="text-sm font-bold">인사 데이터 마감</div>
                  </div>
                </div>
                <div class="flex gap-4">
                  <div class="w-10 text-center">
                    <div class="text-[11px] font-bold uppercase text-slate-400">Wed</div>
                    <div class="text-lg font-black">20</div>
                  </div>
                  <div class="flex-1 rounded-2xl border-l-4 border-amber-400 bg-slate-50 px-4 py-3">
                    <div class="text-sm font-bold">지원금 신청 마감</div>
                  </div>
                </div>
              </div>
            </article>
          </div>
        </section>
      </main>
    </div>
  </div>
</body>
</html>
