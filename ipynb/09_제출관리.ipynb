# %%
<!DOCTYPE html>
<html lang="ko">
<head>
  <meta charset="utf-8"/>
  <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
  <title>제출 관리 | 지원금 워크플로우 매니저</title>
  <script src="https://cdn.tailwindcss.com?plugins=forms,container-queries"></script>
  <link rel="preconnect" href="https://fonts.googleapis.com"/>
  <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin/>
  <link href="https://fonts.googleapis.com/css2?family=Inter:wght@400;500;600;700;800;900&family=Noto+Sans+KR:wght@400;500;700;800&display=swap" rel="stylesheet"/>
  <link href="https://fonts.googleapis.com/css2?family=Material+Symbols+Outlined:wght,FILL@200..700,0..1" rel="stylesheet"/>
  <script>
    tailwind.config = {
      darkMode: "class",
      theme: {
        extend: {
          colors: {
            primary: "#0B5FFF",
            "primary-dark": "#0847C7"
          },
          boxShadow: {
            soft: "0 8px 24px rgba(15,23,42,.06)"
          },
          borderRadius: {
            xl: "1rem",
            "2xl": "1.25rem"
          }
        }
      }
    }
  </script>
  <style>
  :root{
    --primary:#0B5FFF;
    --primary-2:#0847C7;
    --bg:#F6F8FC;
    --line:#E5EAF2;
    --text:#0F172A;
    --muted:#64748B;
    --card:#FFFFFF;
    --success:#16A34A;
    --warning:#D97706;
    --danger:#DC2626;
  }
  body{font-family:'Inter','Noto Sans KR',sans-serif;background:var(--bg);color:var(--text);}
  .page-shell{min-height:100vh;}
  .sidebar-link{display:flex;align-items:center;gap:.75rem;border-radius:1rem;padding:.875rem 1rem;font-weight:600;color:#334155;transition:all .18s ease;}
  .sidebar-link:hover{background:#eef4ff;color:var(--primary);}
  .sidebar-link.active{background:#eaf1ff;color:var(--primary);}
  .badge{display:inline-flex;align-items:center;gap:.35rem;border-radius:999px;padding:.3rem .7rem;font-size:.78rem;font-weight:700;}
  .badge-blue{background:#eaf1ff;color:var(--primary);}
  .badge-green{background:#eaf8ef;color:var(--success);}
  .badge-amber{background:#fff6e8;color:var(--warning);}
  .badge-red{background:#fdecec;color:var(--danger);}
  .card{background:var(--card);border:1px solid var(--line);border-radius:1.25rem;box-shadow:0 8px 24px rgba(15,23,42,.04);}
  .card-title{font-size:1.05rem;font-weight:800;letter-spacing:-.01em;}
  .muted{color:var(--muted);}
  .step-chip{border:1px solid var(--line);background:#fff;border-radius:1rem;padding:1rem;min-width:170px;}
  .step-chip.active{background:linear-gradient(135deg,var(--primary),var(--primary-2));color:#fff;border-color:transparent;box-shadow:0 12px 30px rgba(11,95,255,.25);}
  .step-chip.done{border-color:#D8E7FF;background:#F9FBFF;}
  .metric{font-size:2rem;font-weight:900;letter-spacing:-.03em;}
  .pill-input{border:1px solid var(--line);border-radius:999px;background:#fff;padding:.8rem 1rem;}
  .table-head{background:#F8FAFC;color:#475569;font-size:.84rem;font-weight:700;}
  .table-row{border-top:1px solid var(--line);}
  .section-grid{display:grid;grid-template-columns:2fr 1fr;gap:1.5rem;}
  @media (max-width: 1100px){
    .section-grid{grid-template-columns:1fr;}
  }
  .hero-grid{display:grid;grid-template-columns:1.4fr .8fr;gap:1.25rem;}
  @media (max-width: 900px){
    .hero-grid{grid-template-columns:1fr;}
  }
</style>
</head>
<body>
  <div class="page-shell flex">
    
    <aside class="w-[280px] shrink-0 border-r border-slate-200 bg-white/90 backdrop-blur">
      <div class="flex h-full flex-col px-5 py-6">
        <div class="mb-8">
          <div class="text-[30px] font-black tracking-[-0.03em] text-[var(--primary)]">지원금 워크플로우 매니저</div>
          <div class="mt-1 text-sm font-medium text-slate-500">지원금 신청 전 과정을 한 화면에서 관리</div>
        </div>
        <div class="mb-4 rounded-2xl bg-slate-50 p-4">
          <div class="text-xs font-bold uppercase tracking-[0.18em] text-slate-400">현재 선택 기업</div>
          <div class="mt-2 flex items-center justify-between gap-3">
            <div>
              <div class="font-bold">(주)테크원</div>
              <div class="text-sm text-slate-500">제조업 · 반도체 장비</div>
            </div>
            <span class="material-symbols-outlined text-slate-400">expand_more</span>
          </div>
        </div>
        <nav class="space-y-2 overflow-y-auto pr-1">
        <a href="platform_02.html" class="sidebar-link">
          <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700">
            <span class="material-symbols-outlined text-[20px]">storefront</span>
          </span>
          <span class="flex-1">
            <span class="block text-xs text-slate-400">STEP 01</span>
            <span class="block">기업 등록</span>
          </span>
        </a>
        <a href="platform_03.html" class="sidebar-link">
          <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700">
            <span class="material-symbols-outlined text-[20px]">groups</span>
          </span>
          <span class="flex-1">
            <span class="block text-xs text-slate-400">STEP 02</span>
            <span class="block">직원 업로드</span>
          </span>
        </a>
        <a href="platform_05.html" class="sidebar-link">
          <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700">
            <span class="material-symbols-outlined text-[20px]">event_note</span>
          </span>
          <span class="flex-1">
            <span class="block text-xs text-slate-400">STEP 03</span>
            <span class="block">인사 이벤트</span>
          </span>
        </a>
        <a href="platform_06.html" class="sidebar-link">
          <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700">
            <span class="material-symbols-outlined text-[20px]">monitoring</span>
          </span>
          <span class="flex-1">
            <span class="block text-xs text-slate-400">STEP 04</span>
            <span class="block">지원금 진단</span>
          </span>
        </a>
        <a href="platform_07.html" class="sidebar-link">
          <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700">
            <span class="material-symbols-outlined text-[20px]">quiz</span>
          </span>
          <span class="flex-1">
            <span class="block text-xs text-slate-400">STEP 05</span>
            <span class="block">추가 질문</span>
          </span>
        </a>
        <a href="platform_08.html" class="sidebar-link">
          <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700">
            <span class="material-symbols-outlined text-[20px]">balance</span>
          </span>
          <span class="flex-1">
            <span class="block text-xs text-slate-400">STEP 06</span>
            <span class="block">충돌 검토</span>
          </span>
        </a>
        <a href="platform_01.html" class="sidebar-link">
          <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700">
            <span class="material-symbols-outlined text-[20px]">folder_open</span>
          </span>
          <span class="flex-1">
            <span class="block text-xs text-slate-400">STEP 07</span>
            <span class="block">신청 준비</span>
          </span>
        </a>
        <a href="platform_09.html" class="sidebar-link">
          <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700">
            <span class="material-symbols-outlined text-[20px]">edit_document</span>
          </span>
          <span class="flex-1">
            <span class="block text-xs text-slate-400">STEP 08</span>
            <span class="block">신청서 자동작성</span>
          </span>
        </a>
        <a href="platform_10.html" class="sidebar-link active">
          <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700">
            <span class="material-symbols-outlined text-[20px]">task</span>
          </span>
          <span class="flex-1">
            <span class="block text-xs text-slate-400">STEP 09</span>
            <span class="block">제출 관리</span>
          </span>
        </a>
        <a href="platform_11.html" class="sidebar-link">
          <span class="inline-flex h-10 w-10 items-center justify-center rounded-xl bg-slate-100 text-slate-700">
            <span class="material-symbols-outlined text-[20px]">shield</span>
          </span>
          <span class="flex-1">
            <span class="block text-xs text-slate-400">STEP 10</span>
            <span class="block">사후관리</span>
          </span>
        </a></nav>
        <div class="mt-auto pt-6">
          <div class="rounded-2xl bg-slate-900 px-4 py-5 text-white">
            <div class="text-xs font-bold uppercase tracking-[0.18em] text-slate-400">운영 메모</div>
            <p class="mt-2 text-sm leading-6 text-slate-200">브랜드, 용어, 상태값, 버튼 위치를 전 화면에서 통일했습니다.</p>
          </div>
        </div>
      </div>
    </aside>
    
    <div class="flex min-w-0 flex-1 flex-col">
      
    <header class="sticky top-0 z-10 border-b border-slate-200 bg-white/85 backdrop-blur">
      <div class="flex h-20 items-center justify-between gap-6 px-8">
        <div class="flex items-center gap-4">
          <span class="badge badge-blue">워크플로우 진행 중</span>
          <div>
            <div class="text-sm font-semibold text-slate-500">기업명</div>
            <div class="font-bold">(주)테크원</div>
          </div>
        </div>
        <div class="flex min-w-0 flex-1 items-center justify-end gap-4">
          <div class="pill-input hidden w-full max-w-md items-center gap-2 md:flex">
            <span class="material-symbols-outlined text-slate-400">search</span>
            <span class="text-sm text-slate-400">검색, 담당자, 서류명, 제도명…</span>
          </div>
          <button class="inline-flex h-11 w-11 items-center justify-center rounded-2xl border border-slate-200 bg-white text-slate-600">
            <span class="material-symbols-outlined">notifications</span>
          </button>
          <button class="inline-flex items-center gap-3 rounded-2xl border border-slate-200 bg-white px-4 py-2.5">
            <span class="inline-flex h-9 w-9 items-center justify-center rounded-full bg-emerald-50 text-emerald-700 text-sm font-bold">TW</span>
            <span class="text-sm font-semibold">제출 관리</span>
          </button>
        </div>
      </div>
    </header>
    
      <main class="flex-1 space-y-8 px-8 py-8">
        
    <section class="hero-grid">
      <div class="card p-7">
        <div class="flex flex-wrap items-start justify-between gap-4">
          <div>
            <div class="badge badge-blue">STEP 09</div>
            <h1 class="mt-4 text-[38px] font-black tracking-[-0.04em]">제출 관리</h1>
            <p class="mt-3 max-w-3xl text-base leading-7 text-slate-500">접수/보완/반려 상태와 운영기관 커뮤니케이션 이력을 동일한 리스트 구조로 정리했습니다.</p>
          </div>
          <div class="flex flex-wrap gap-3"><button class="inline-flex items-center gap-2 rounded-2xl px-5 py-3 text-sm font-semibold border transition bg-white text-slate-700 border-[var(--line)] hover:bg-slate-50"><span>원본 신청서 보기</span></button><button class="inline-flex items-center gap-2 rounded-2xl px-5 py-3 text-sm font-semibold border transition bg-[var(--primary)] text-white border-[var(--primary)] shadow-[0_10px_24px_rgba(11,95,255,.22)] hover:bg-[var(--primary-2)]"><span class="material-symbols-outlined text-[18px]">arrow_forward</span><span>요청 정보 제출</span></button></div>
        </div>
      </div>
      <div class="grid gap-4">
    <div class="card p-6">
      <div class="flex items-start justify-between gap-3">
        <div>
          <p class="text-sm font-semibold text-slate-500">전체 제출 건</p>
          <p class="metric mt-3">12건</p>
          <p class="mt-2 text-sm muted">진행 중 5건 · 완료 7건</p>
        </div>
        <span class="badge badge-blue">운영기관별 집계</span>
      </div>
    </div>
    <div class="card p-6">
      <div class="flex items-start justify-between gap-3">
        <div>
          <p class="text-sm font-semibold text-slate-500">보완 요청</p>
          <p class="metric mt-3">3건</p>
          <p class="mt-2 text-sm muted">응답 기한이 설정된 항목</p>
        </div>
        <span class="badge badge-amber">우선 대응</span>
      </div>
    </div>
    <div class="card p-6">
      <div class="flex items-start justify-between gap-3">
        <div>
          <p class="text-sm font-semibold text-slate-500">완료율</p>
          <p class="metric mt-3">78%</p>
          <p class="mt-2 text-sm muted">이번 분기 기준 제출 프로세스</p>
        </div>
        <span class="badge badge-green">증가 추세</span>
      </div>
    </div></div>
    </section>
    
        
    <section class="overflow-x-auto pb-2">
      <div class="flex min-w-max items-stretch gap-4"><div class="step-chip done"><div class="text-[11px] font-bold uppercase tracking-[0.18em] opacity-60">STEP 01</div><div class="mt-2 font-bold">기업 등록</div><div class="mt-2 text-sm opacity-80">완료</div></div><div class="step-chip done"><div class="text-[11px] font-bold uppercase tracking-[0.18em] opacity-60">STEP 02</div><div class="mt-2 font-bold">직원 업로드</div><div class="mt-2 text-sm opacity-80">완료</div></div><div class="step-chip done"><div class="text-[11px] font-bold uppercase tracking-[0.18em] opacity-60">STEP 03</div><div class="mt-2 font-bold">인사 이벤트</div><div class="mt-2 text-sm opacity-80">완료</div></div><div class="step-chip done"><div class="text-[11px] font-bold uppercase tracking-[0.18em] opacity-60">STEP 04</div><div class="mt-2 font-bold">지원금 진단</div><div class="mt-2 text-sm opacity-80">완료</div></div><div class="step-chip done"><div class="text-[11px] font-bold uppercase tracking-[0.18em] opacity-60">STEP 05</div><div class="mt-2 font-bold">추가 질문</div><div class="mt-2 text-sm opacity-80">완료</div></div><div class="step-chip done"><div class="text-[11px] font-bold uppercase tracking-[0.18em] opacity-60">STEP 06</div><div class="mt-2 font-bold">충돌 검토</div><div class="mt-2 text-sm opacity-80">완료</div></div><div class="step-chip done"><div class="text-[11px] font-bold uppercase tracking-[0.18em] opacity-60">STEP 07</div><div class="mt-2 font-bold">신청 준비</div><div class="mt-2 text-sm opacity-80">완료</div></div><div class="step-chip done"><div class="text-[11px] font-bold uppercase tracking-[0.18em] opacity-60">STEP 08</div><div class="mt-2 font-bold">신청서 자동작성</div><div class="mt-2 text-sm opacity-80">완료</div></div><div class="step-chip active"><div class="text-[11px] font-bold uppercase tracking-[0.18em] opacity-60">STEP 09</div><div class="mt-2 font-bold">제출 관리</div><div class="mt-2 text-sm opacity-90">현재 작업 단계</div></div><div class="step-chip "><div class="text-[11px] font-bold uppercase tracking-[0.18em] opacity-60">STEP 10</div><div class="mt-2 font-bold">사후관리</div><div class="mt-2 text-sm opacity-70">대기</div></div></div>
    </section>
    
        
    <section class="space-y-4">
      <div>
        <h2 class="text-[22px] font-black tracking-[-0.02em]">접수 현황과 이력</h2>
        <p class="mt-1 text-sm text-slate-500">리스트형 운영 화면의 구조와 상태 배지를 동일 기준으로 정리했습니다.</p>
      </div>
      
      <div class="grid gap-6 lg:grid-cols-[1.4fr_.9fr]">
        <div class="space-y-6">
          
    <div class="card overflow-hidden">
      <table class="min-w-full text-sm">
        <thead class="table-head"><tr><th class="px-4 py-3 text-left">제도명</th><th class="px-4 py-3 text-left">운영기관</th><th class="px-4 py-3 text-left">현재 상태</th><th class="px-4 py-3 text-left">마감/응답일</th><th class="px-4 py-3 text-left">액션</th></tr></thead>
        <tbody><tr class="table-row"><td class="px-4 py-3 align-top text-sm text-slate-700">청년일자리도약장려금</td><td class="px-4 py-3 align-top text-sm text-slate-700">고용노동부</td><td class="px-4 py-3 align-top text-sm text-slate-700"><span class='badge badge-blue'>접수 완료</span></td><td class="px-4 py-3 align-top text-sm text-slate-700">2026.03.20</td><td class="px-4 py-3 align-top text-sm text-slate-700">접수증 확인</td></tr><tr class="table-row"><td class="px-4 py-3 align-top text-sm text-slate-700">고용유지지원금</td><td class="px-4 py-3 align-top text-sm text-slate-700">고용센터</td><td class="px-4 py-3 align-top text-sm text-slate-700"><span class='badge badge-amber'>보완 요청</span></td><td class="px-4 py-3 align-top text-sm text-slate-700">2026.03.18</td><td class="px-4 py-3 align-top text-sm text-slate-700">보완자료 제출</td></tr><tr class="table-row"><td class="px-4 py-3 align-top text-sm text-slate-700">고령자 계속고용장려금</td><td class="px-4 py-3 align-top text-sm text-slate-700">고용센터</td><td class="px-4 py-3 align-top text-sm text-slate-700"><span class='badge badge-green'>완료</span></td><td class="px-4 py-3 align-top text-sm text-slate-700">2026.03.15</td><td class="px-4 py-3 align-top text-sm text-slate-700">보관</td></tr><tr class="table-row"><td class="px-4 py-3 align-top text-sm text-slate-700">워라밸일자리 장려금</td><td class="px-4 py-3 align-top text-sm text-slate-700">지방고용청</td><td class="px-4 py-3 align-top text-sm text-slate-700"><span class='badge badge-red'>반려</span></td><td class="px-4 py-3 align-top text-sm text-slate-700">2026.03.11</td><td class="px-4 py-3 align-top text-sm text-slate-700">사유 확인</td></tr></tbody>
      </table>
    </div>
          
    <div class="card overflow-hidden">
      <table class="min-w-full text-sm">
        <thead class="table-head"><tr><th class="px-4 py-3 text-left">일시</th><th class="px-4 py-3 text-left">채널</th><th class="px-4 py-3 text-left">내용</th><th class="px-4 py-3 text-left">담당자</th></tr></thead>
        <tbody><tr class="table-row"><td class="px-4 py-3 align-top text-sm text-slate-700">03.12 10:22</td><td class="px-4 py-3 align-top text-sm text-slate-700">기관 메시지</td><td class="px-4 py-3 align-top text-sm text-slate-700">보완자료로 신규 채용자 계약서 제출 요청</td><td class="px-4 py-3 align-top text-sm text-slate-700">박수진</td></tr><tr class="table-row"><td class="px-4 py-3 align-top text-sm text-slate-700">03.12 14:40</td><td class="px-4 py-3 align-top text-sm text-slate-700">이메일</td><td class="px-4 py-3 align-top text-sm text-slate-700">접수 완료 안내 및 접수번호 전달</td><td class="px-4 py-3 align-top text-sm text-slate-700">시스템</td></tr><tr class="table-row"><td class="px-4 py-3 align-top text-sm text-slate-700">03.13 09:05</td><td class="px-4 py-3 align-top text-sm text-slate-700">내부 메모</td><td class="px-4 py-3 align-top text-sm text-slate-700">대표자 확인 후 오늘 중 보완 예정</td><td class="px-4 py-3 align-top text-sm text-slate-700">김도윤</td></tr></tbody>
      </table>
    </div>
        </div>
        <div class="space-y-6">
          
    <div class="card p-6">
      <div class="flex items-center gap-3">
        <span class="badge badge-green"><span class="material-symbols-outlined text-[16px]">task_alt</span>상태값 규칙</span>
      </div>
      <ul class="mt-4 space-y-3 text-sm leading-6 text-slate-700"><li class="flex gap-3"><span class="mt-1 h-2.5 w-2.5 rounded-full bg-slate-300"></span><span>준비중 · 접수완료 · 보완요청 · 반려 · 완료 5종으로 통일</span></li><li class="flex gap-3"><span class="mt-1 h-2.5 w-2.5 rounded-full bg-slate-300"></span><span>상태색과 배지 문구를 모든 화면에서 동일 적용</span></li></ul>
    </div>
          
    <div class="card p-6">
      <div class="flex items-center gap-3">
        <span class="badge badge-amber"><span class="material-symbols-outlined text-[16px]">warning</span>즉시 대응 필요</span>
      </div>
      <ul class="mt-4 space-y-3 text-sm leading-6 text-slate-700"><li class="flex gap-3"><span class="mt-1 h-2.5 w-2.5 rounded-full bg-slate-300"></span><span>고용유지지원금 보완 기한 2일 남음</span></li><li class="flex gap-3"><span class="mt-1 h-2.5 w-2.5 rounded-full bg-slate-300"></span><span>반려 사유 확인 후 재신청 여부 결정</span></li></ul>
    </div>
        </div>
      </div>
    
    </section>
      </main>
    </div>
  </div>
</body>
</html>
